# %%
import module_2
module_2.plot()
# Out:
# ...
# FigureWidget({
#     'data': [{'name': 'NFW',
#               'type': 'scatter',
#               'uid': 'd5353106-0f90-4fe3-aff6-fa09c24f8f0a',
#               'x': array([ 0.1       ,  0.6040404 ,  1.10808081,  1.61212121,  2.11616162,
#                            2.62020202,  3.12424242,  3.62828283,  4.13232323,  4.63636364,
#                            5.14040404,  5.64444444,  6.14848485,  6.65252525,  7.15656566,
#                            7.66060606,  8.16464646,  8.66868687,  9.17272727,  9.67676768,
#                           10.18080808, 10.68484848, 11.18888889, 11.69292929, 12.1969697 ,
#                           12.7010101 , 13.20505051, 13.70909091, 14.21313131, 14.71717172,
#                           15.22121212, 15.72525253, 16.22929293, 16.73333333, 17.23737374,
#                           17.74141414, 18.24545455, 18.74949495, 19.25353535, 19.75757576,
#                           20.26161616, 20.76565657, 21.26969697, 21.77373737, 22.27777778,
# ...
